# %% [markdown]
# <b>Getting Started with Jupyter</b>

# %%
#The "magic" command below imports numpy and pyplot and
# sets us up to make nice interactive plots within the notebook
# %pylab notebook

#Shouldn't be necessary, but let's make sure we're in the right directory
# with all our stuff.
# %cd C:\Users\mrever\Documents\packt_CV\Section1-Getting_started
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\mrever\Documents\packt_CV\Section1-Getting_started

# %%
#Let's make sure our libraries are installed correctly
import cv2
import tensorflow as tf
import dlib
import pytesseract as ptess
# Out:
# C:\Users\mrever\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-9a3775b5528d> in <module>()
#       2 import cv2
#       3 import tensorflow as tf
# ----> 4 import dlib
#       5 import pytesseract as ptess
#
# ModuleNotFoundError: No module named 'dlib'

# %%
#Here's a nice way to get help on a module/function from within the notebook
tf.Graph?

# %%
#We can run shell commands here too--very handy!
# !ls
# Out:
# Megamind.avi
# Megamind.mp4
# Packt_CV_w_Python3_Getting_Started_with_Jupyter_notebooks.ipynb
# butterfly.jpg

# %%
#Let's display an image with some widgets to pan/zoom etc.
#---Note that imread, figure, and imshow come from matplotlib.pyplot,
#---but %pylab notebook imported them into the namespace.
#---This is good for notebooks, but not necessarily good for general practice.

testim = imread('butterfly.jpg')
figure()
imshow(testim)
# Out:
# <img src="data:image/png;base64,..." width="459.5">

# %%
#Here's a nice way to watch a video within the notebook--will be useful
# when we want to work with videos
import io
import base64
from IPython.display import HTML

def playvideo(filename):
    video = io.open(filename, 'r+b').read()
    encoded = base64.b64encode(video)
    return HTML(data='''<video alt="test" controls>
                    <source src="data:video/mp4;base64,{0}" type="video/mp4"/>
                 </video>'''.format(encoded.decode('ascii')))

# %%
#Now play...
playvideo('./Megamind.mp4')
# Out:
# <video alt="test" controls>
#                     <source src="data:video/mp4;base64,..." type="video/mp4"/>
#                  </video>
